# %%
import os, subprocess
import pandas as pd
import numpy as np
from IPython.display import display

# %% [markdown]
# # Combine features

# %%
# check features folders
subprocess.check_output(["ls", "features"]).splitlines()
# Out:
# ['baseline_extend.pkl.bz2',
#  'baseline.pkl.bz2',
#  'bureau_balance.pkl.bz2',
#  'bureau.pkl.bz2',
#  'pdf_features_label.pkl.bz2']

# %%
# specified features set for joining
ls_feat_file = [
    "baseline.pkl.bz2",
    "baseline_extend.pkl.bz2",
    "bureau.pkl.bz2",
    "bureau_balance.pkl.bz2"
]

# %%
# %%time
# use first features for base joined
feat_path = os.path.join("features", ls_feat_file[0])
pdf_combined = pd.read_pickle(feat_path, compression="bz2")

# join next features set
for fname in ls_feat_file[1:]:
    feat_path = os.path.join("features", fname)
    pdf_feat = pd.read_pickle(feat_path)
    pdf_combined = pdf_combined.merge(pdf_feat, on="SK_ID_CURR", how="left")

print("rows, columns", pdf_combined.shape)
pdf_combined.head()   
ls_features = [feat for feat in pdf_combined.columns if feat not in ["SK_ID_CURR"]]
# Out:
# ('rows, columns', (356255, 354))
# CPU times: user 16.1 s, sys: 1.82 s, total: 17.9 s
# Wall time: 11.7 s

# %% [markdown]
# # join with label

# %%
pdf_tvt = pd.read_pickle("pdf_tvt_extend.pkl", compression="bz2")
print(pdf_tvt.shape)
display(pdf_tvt.head())
# Out:
# (356255, 3)
#    SK_ID_CURR  TARGET tvt_code
# 0      100002       1    train
# 1      100003       0    train
# 2      100004       0    train
# 3      100006       0    train
# 4      100007       0    train

# %%
pdf_tvt["tvt_code"].value_counts()
# Out:
# train          216948
# kaggle_test     48744
# test            46127
# val             44436
# Name: tvt_code, dtype: int64

# %%
pdf_features_label = pdf_tvt.merge(pdf_combined, on="SK_ID_CURR", how="left")
print(pdf_features_label.shape)
display(pdf_features_label.head().T)
# Out:
# (356255, 356)
#                                                 0       1       2       3  \
# SK_ID_CURR                                 100002  100003  100004  100006
# TARGET                                          1       0       0       0
# tvt_code                                    train   train   train   train
# is_FLAG_EMP_PHONE                               1       1       1       1
# is_FLAG_WORK_PHONE                              0       0       1       0
# is_FLAG_PHONE                                   1       1       1       0
# is_FLAG_EMAIL                                   0       0       0       0
# is_REG_REGION_NOT_LIVE_REGION                   0       0       0       0
# is_REG_REGION_NOT_WORK_REGION                   0       0       0       0
# is_LIVE_REGION_NOT_WORK_REGION                  0       0       0       0
# is_REG_CITY_NOT_WORK_CITY                       0       0       0       0
# is_LIVE_CITY_NOT_WORK_CITY                      0       0       0       0
# is_FLAG_DOCUMENT_3                              1       1       0       1
# is_FLAG_DOCUMENT_5                              0       0       0       0
# is_FLAG_DOCUMENT_6                              0       0       0       0
# is_FLAG_DOCUMENT_8                              0       0       0       0
# is_FLAG_DOCUMENT_9                              0       0       0       0
# is_REGION_RATING_CLIENT                         2       1       2       2
# is_REGION_RATING_CLIENT_W_CITY                  2       1       2       2
# NAME_INCOME_TYPE_Working                        1       0       1       1
# NAME_INCOME_TYPE_State_servant                  0       1       0       0
# NAME_INCOME_TYPE_Commercial_associate           0       0       0       0
# NAME_INCOME_TYPE_Pensioner                      0       0       0       0
# NAME_INCOME_TYPE_Unemployed                     0       0       0       0
# NAME_INCOME_TYPE_Student                        0       0       0       0
# NAME_INCOME_TYPE_Businessman                    0       0       0       0
# NAME_INCOME_TYPE_Maternity_leave                0       0       0       0
# FONDKAPREMONT_MODE_reg_oper_account             1       1       0       0
# FONDKAPREMONT_MODE_org_spec_account             0       0       0       0
# FONDKAPREMONT_MODE_reg_oper_spec_account        0       0       0       0
# ...                                           ...     ...     ...     ...
# STATUS_2_sum_mean                               0     NaN     NaN     NaN
# STATUS_2_sum_std                                0     NaN     NaN     NaN
# STATUS_5_sum_min                                0     NaN     NaN     NaN
# STATUS_5_sum_max                                0     NaN     NaN     NaN
# STATUS_5_sum_mean                               0     NaN     NaN     NaN
# STATUS_5_sum_std                                0     NaN     NaN     NaN
# STATUS_0_sum_min                                2     NaN     NaN     NaN
# STATUS_0_sum_max                               18     NaN     NaN     NaN
# STATUS_0_sum_mean                           5.625     NaN     NaN     NaN
# STATUS_0_sum_std                          5.18066     NaN     NaN     NaN
# STATUS_1_sum_min                                0     NaN     NaN     NaN
# STATUS_1_sum_max                                6     NaN     NaN     NaN
# STATUS_1_sum_mean                           3.375     NaN     NaN     NaN
# STATUS_1_sum_std                          2.87539     NaN     NaN     NaN
# STATUS_3_sum_min                                0     NaN     NaN     NaN
# STATUS_3_sum_max                                0     NaN     NaN     NaN
# STATUS_3_sum_mean                               0     NaN     NaN     NaN
# STATUS_3_sum_std                                0     NaN     NaN     NaN
# STATUS_X_sum_min                                0     NaN     NaN     NaN
# STATUS_X_sum_max                                3     NaN     NaN     NaN
# STATUS_X_sum_mean                           1.875     NaN     NaN     NaN
# STATUS_X_sum_std                           1.3562     NaN     NaN     NaN
# STATUS_4_max_max                                0     NaN     NaN     NaN
# STATUS_C_max_max                                1     NaN     NaN     NaN
# STATUS_2_max_max                                0     NaN     NaN     NaN
# STATUS_0_max_max                                1     NaN     NaN     NaN
# STATUS_3_max_max                                0     NaN     NaN     NaN
# STATUS_X_max_max                                1     NaN     NaN     NaN
# STATUS_1_max_max                                1     NaN     NaN     NaN
# STATUS_5_max_max                                0     NaN     NaN     NaN
#
#                                                4
# SK_ID_CURR                                100007
# TARGET                                         0
# tvt_code                                   train
# is_FLAG_EMP_PHONE                              1
# is_FLAG_WORK_PHONE                             0
# is_FLAG_PHONE                                  0
# is_FLAG_EMAIL                                  0
# is_REG_REGION_NOT_LIVE_REGION                  0
# is_REG_REGION_NOT_WORK_REGION                  0
# is_LIVE_REGION_NOT_WORK_REGION                 0
# is_REG_CITY_NOT_WORK_CITY                      1
# is_LIVE_CITY_NOT_WORK_CITY                     1
# is_FLAG_DOCUMENT_3                             0
# is_FLAG_DOCUMENT_5                             0
# is_FLAG_DOCUMENT_6                             0
# is_FLAG_DOCUMENT_8                             1
# is_FLAG_DOCUMENT_9                             0
# is_REGION_RATING_CLIENT                        2
# is_REGION_RATING_CLIENT_W_CITY                 2
# NAME_INCOME_TYPE_Working                       1
# NAME_INCOME_TYPE_State_servant                 0
# NAME_INCOME_TYPE_Commercial_associate          0
# NAME_INCOME_TYPE_Pensioner                     0
# NAME_INCOME_TYPE_Unemployed                    0
# NAME_INCOME_TYPE_Student                       0
# NAME_INCOME_TYPE_Businessman                   0
# NAME_INCOME_TYPE_Maternity_leave               0
# FONDKAPREMONT_MODE_reg_oper_account            0
# FONDKAPREMONT_MODE_org_spec_account            0
# FONDKAPREMONT_MODE_reg_oper_spec_account       0
# ...                                          ...
# STATUS_2_sum_mean                            NaN
# STATUS_2_sum_std                             NaN
# STATUS_5_sum_min                             NaN
# STATUS_5_sum_max                             NaN
# STATUS_5_sum_mean                            NaN
# STATUS_5_sum_std                             NaN
# STATUS_0_sum_min                             NaN
# STATUS_0_sum_max                             NaN
# STATUS_0_sum_mean                            NaN
# STATUS_0_sum_std                             NaN
# STATUS_1_sum_min                             NaN
# STATUS_1_sum_max                             NaN
# STATUS_1_sum_mean                            NaN
# STATUS_1_sum_std                             NaN
# STATUS_3_sum_min                             NaN
# STATUS_3_sum_max                             NaN
# STATUS_3_sum_mean                            NaN
# STATUS_3_sum_std                             NaN
# STATUS_X_sum_min                             NaN
# STATUS_X_sum_max                             NaN
# STATUS_X_sum_mean                            NaN
# STATUS_X_sum_std                             NaN
# STATUS_4_max_max                             NaN
# STATUS_C_max_max                             NaN
# STATUS_2_max_max                             NaN
# STATUS_0_max_max                             NaN
# STATUS_3_max_max                             NaN
# STATUS_X_max_max                             NaN
# STATUS_1_max_max                             NaN
# STATUS_5_max_max                             NaN
#
# [356 rows x 5 columns]

# %%
# %%time
# save combined features with label
pdf_features_label.to_pickle(os.path.join("features", "pdf_features_label.pkl.bz2"), compression="bz2")
# Out:
# CPU times: user 46.9 s, sys: 845 ms, total: 47.7 s
# Wall time: 47.8 s
